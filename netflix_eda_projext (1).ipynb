# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mymoviedb.csv', engine='python')

# %%
df
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9832   1973-10-15                              Badlands
# 9833   2020-10-01                      Violent Delights
# 9834   2016-05-06                          The Offering
# 9835   2021-03-31  The United States vs. Billie Holiday
# 9836   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df.shape
# Out:
# (9837, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
df['Release_Date'].unique()
# Out:
# array(['2021-12-15', '2022-03-01', '2022-02-25', ..., '1974-11-06',
#        '1973-10-15', '1984-09-23'], dtype=object)

# %%
df['Release_Date']=pd.to_datetime(df['Release_Date'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 691.8+ KB

# %%
df['Release_year']=df['Release_Date'].dt.year
df['Release_month']=df['Release_Date'].dt.month
df['Release_Day']=df['Release_Date'].dt.day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
#  9   Release_year       9827 non-null   float64
#  10  Release_month      9827 non-null   float64
#  11  Release_Day        9827 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(7)
# memory usage: 922.3+ KB

# %%
df=df.drop('Release_Date',axis=1,inplace=True)

# %%
df
# Out:
#                                      Title  \
# 0                  Spider-Man: No Way Home
# 1                               The Batman
# 2                                  No Exit
# 3                                  Encanto
# 4                           The King's Man
# ...                                    ...
# 9832                              Badlands
# 9833                      Violent Delights
# 9834                          The Offering
# 9835  The United States vs. Billie Holiday
# 9836                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# 3     The tale of an extraordinary family, the Madri...    2402.201
# 4     As a collection of history's worst tyrants and...    1895.511
# ...

# %%
col=['Overview','Original_Language','Poster_Url']
df.drop(col,axis=1,inplace=True)

# %%
df
# Out:
#                                      Title  Popularity Vote_Count  \
# 0                  Spider-Man: No Way Home    5083.954       8940
# 1                               The Batman    3827.658       1151
# 2                                  No Exit    2618.087        122
# 3                                  Encanto    2402.201       5076
# 4                           The King's Man    1895.511       1793
# ...                                    ...         ...        ...
# 9832                              Badlands      13.357        896
# 9833                      Violent Delights      13.356          8
# 9834                          The Offering      13.355         94
# 9835  The United States vs. Billie Holiday      13.354        152
# 9836                               Threads      13.354        186
#
#      Vote_Average                               Genre  Release_year  \
# 0             8.3  Action, Adventure, Science Fiction        2021.0
# ...

# %%
df[df['Title'].isnull()]
# Out:
#      Title  Popularity Vote_Count Vote_Average Genre  Release_year  \
# 1106  None         NaN       None         None  None           NaN
# 1107  None         NaN       None         None  None           NaN
# 1108  None         NaN       None         None  None           NaN
# 1109  None         NaN       None         None  None           NaN
# 1110  None         NaN       None         None  None           NaN
# 1111  None         NaN       None         None  None           NaN
# 1112  None         NaN       None         None  None           NaN
# 1113  None         NaN       None         None  None           NaN
# 1114  None         NaN       None         None  None           NaN
#
#       Release_month  Release_Day
# 1106            NaN          NaN
# 1107            NaN          NaN
# 1108            NaN          NaN
# 1109            NaN          NaN
# 1110            NaN          NaN
# 1111            NaN          NaN
# 1112            NaN          NaN
# ...

# %%
df.dropna(subset=['Title'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Title            0
# Popularity       1
# Vote_Count       1
# Vote_Average     1
# Genre            2
# Release_year     1
# Release_month    1
# Release_Day      1
# dtype: int64

# %%
df[df['Genre'].isnull()]
# Out:
#                       Title  Popularity Vote_Count Vote_Average Genre  \
# 1105  Pixie Hollow Bake Off         NaN       None         None  None
# 1115                 61.328         7.1         en    Animation  None
#
#       Release_year  Release_month  Release_Day
# 1105        2013.0           10.0         20.0
# 1115           NaN            NaN          NaN

# %%
df.dropna(subset=['Genre'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Title            0
# Popularity       0
# Vote_Count       0
# Vote_Average     0
# Genre            0
# Release_year     0
# Release_month    0
# Release_Day      0
# dtype: int64

# %%
df
# Out:
#                                      Title  Popularity Vote_Count  \
# 0                  Spider-Man: No Way Home    5083.954       8940
# 1                               The Batman    3827.658       1151
# 2                                  No Exit    2618.087        122
# 3                                  Encanto    2402.201       5076
# 4                           The King's Man    1895.511       1793
# ...                                    ...         ...        ...
# 9832                              Badlands      13.357        896
# 9833                      Violent Delights      13.356          8
# 9834                          The Offering      13.355         94
# 9835  The United States vs. Billie Holiday      13.354        152
# 9836                               Threads      13.354        186
#
#      Vote_Average                               Genre  Release_year  \
# 0             8.3  Action, Adventure, Science Fiction        2021.0
# ...

# %%
df['Genre']=df['Genre'].str.split(', ')
df=df.explode('Genre').reset_index(drop=True)

# %%
df
# Out:
#                                       Title  Popularity Vote_Count  \
# 0                   Spider-Man: No Way Home    5083.954       8940
# 1                   Spider-Man: No Way Home    5083.954       8940
# 2                   Spider-Man: No Way Home    5083.954       8940
# 3                                The Batman    3827.658       1151
# 4                                The Batman    3827.658       1151
# ...                                     ...         ...        ...
# 25787  The United States vs. Billie Holiday      13.354        152
# 25788  The United States vs. Billie Holiday      13.354        152
# 25789                               Threads      13.354        186
# 25790                               Threads      13.354        186
# 25791                               Threads      13.354        186
#
#       Vote_Average            Genre  Release_year  Release_month  Release_Day
# 0              8.3           Action        2021.0           12.0         15.0
# ...

# %%
df.shape
# Out:
# (25792, 8)

# %%
df['Genre'].value_counts().plot.pie(y=df['Genre'],figsize=(25,16),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# drama is the most common genere

# %%
df['Genre'].value_counts().plot.bar(figsize=(15,16))
# Out:
# <Axes: xlabel='Genre'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25792 entries, 0 to 25791
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          25792 non-null  object
#  1   Popularity     25792 non-null  float64
#  2   Vote_Count     25792 non-null  object
#  3   Vote_Average   25792 non-null  object
#  4   Genre          25792 non-null  object
#  5   Release_year   25792 non-null  float64
#  6   Release_month  25792 non-null  float64
#  7   Release_Day    25792 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 1.6+ MB

# %%
df['Vote_Count']=df['Vote_Count'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25792 entries, 0 to 25791
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          25792 non-null  object
#  1   Popularity     25792 non-null  float64
#  2   Vote_Count     25792 non-null  int64
#  3   Vote_Average   25792 non-null  object
#  4   Genre          25792 non-null  object
#  5   Release_year   25792 non-null  float64
#  6   Release_month  25792 non-null  float64
#  7   Release_Day    25792 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.6+ MB

# %%
genre_votes=df.groupby('Genre')['Vote_Count'].sum().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_votes.head(10).values, y=genre_votes.head(10).index)
plt.title('Top 10 Genres by Total Vote Count')
plt.xlabel('Total Votes')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()

# %% [markdown]
# drama has maximum vote count

# %%
df
# Out:
#                                       Title  Popularity  Vote_Count  \
# 0                   Spider-Man: No Way Home    5083.954        8940
# 1                   Spider-Man: No Way Home    5083.954        8940
# 2                   Spider-Man: No Way Home    5083.954        8940
# 3                                The Batman    3827.658        1151
# 4                                The Batman    3827.658        1151
# ...                                     ...         ...         ...
# 25787  The United States vs. Billie Holiday      13.354         152
# 25788  The United States vs. Billie Holiday      13.354         152
# 25789                               Threads      13.354         186
# 25790                               Threads      13.354         186
# 25791                               Threads      13.354         186
#
#       Vote_Average            Genre  Release_year  Release_month  Release_Day
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25792 entries, 0 to 25791
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          25792 non-null  object
#  1   Popularity     25792 non-null  float64
#  2   Vote_Count     25792 non-null  int64
#  3   Vote_Average   25792 non-null  object
#  4   Genre          25792 non-null  object
#  5   Release_year   25792 non-null  float64
#  6   Release_month  25792 non-null  float64
#  7   Release_Day    25792 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# What movie got the highest popularity? what's its genre?

# %%
df[df['Popularity']==df['Popularity'].max()]
# Out:
#                      Title  Popularity  Vote_Count Vote_Average  \
# 0  Spider-Man: No Way Home    5083.954        8940          8.3
# 1  Spider-Man: No Way Home    5083.954        8940          8.3
# 2  Spider-Man: No Way Home    5083.954        8940          8.3
#
#              Genre  Release_year  Release_month  Release_Day
# 0           Action        2021.0           12.0         15.0
# 1        Adventure        2021.0           12.0         15.0
# 2  Science Fiction        2021.0           12.0         15.0

# %% [markdown]
# Spider-Man: No Way Home has git highest popularity and its genere is Action,Adventure and Science Fiction

# %% [markdown]
# What movie got the lowest popularity? what's its genre?

# %%
df[df['Popularity']==df['Popularity'].min()]
# Out:
#                                       Title  Popularity  Vote_Count  \
# 25786  The United States vs. Billie Holiday      13.354         152
# 25787  The United States vs. Billie Holiday      13.354         152
# 25788  The United States vs. Billie Holiday      13.354         152
# 25789                               Threads      13.354         186
# 25790                               Threads      13.354         186
# 25791                               Threads      13.354         186
#
#       Vote_Average            Genre  Release_year  Release_month  Release_Day
# 25786          6.7            Music        2021.0            3.0         31.0
# 25787          6.7            Drama        2021.0            3.0         31.0
# 25788          6.7          History        2021.0            3.0         31.0
# 25789          7.8              War        1984.0            9.0         23.0
# 25790          7.8            Drama        1984.0            9.0         23.0
# ...

# %% [markdown]
# 	The United States vs. Billie Holiday and Threads is least popular movie and genre is Music,Drama,History,War and Science Fiction

# %% [markdown]
# Which year has the most filmmed movies?

# %%
year = df['Release_year'].value_counts().idxmax()
count = df['Release_year'].value_counts().max()
print("Year with most movies:", year,":",count)
# Out:
# Year with most movies: 2021.0 : 1638

# %% [markdown]
# 2021 has realesed most movies
